# %% [markdown]
# # FNO for virtual damage sensor

# %%
# packages
import torch
import matplotlib.pyplot as plt
import numpy as np
import sys
from neuralop.models import FNO
from neuralop import Trainer
from neuralop.training import AdamW
from neuralop.utils import count_model_params
from neuralop import LpLoss, H1Loss
from pathlib import Path
from nopkit.data import load_damage_sensor_dataset
from nopkit.mask import MaskGenerator
from nopkit.plot import data_image, pred_plot, pred_anim, pred_voxel

device = 'cuda'

# %%
# Using Saikat's mask
gen = MaskGenerator(grid_shape=(32, 32))

pos = [
    (31, 16),
    (1, 31), (5, 31), (9, 31), (13, 31),
    (17, 31), (21, 31), (25, 31), (29, 31),
]
masks = gen.generate_from_positions([pos])
gen.plot()
gen.save("../data/damage_sensor/mask_8.pt")
# Out:
# c:\workspace\no_playground\neuralop-playground\nopkit_pkg\nopkit\mask.py:53: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\utils\tensor_new.cpp:281.)
#   self.masks = torch.tensor(mask_list, dtype=torch.float32) # (n_masks, height, width)

# %%
# load data
data_dir = Path("../data/damage_sensor")

train_loader, test_loaders, data_processor = load_damage_sensor_dataset(
    ramps_path=data_dir / "ramps_n500_res32.pt",
    damage_path=data_dir / "damage_n500_t175_res32.pt",
    defgrad_path=data_dir / "defgrad_n500_t175_res32.pt",
    elec_path=data_dir / "elec_n500_t175_res32.pt",
    masks_path=data_dir / "mask_8.pt",
    n_train=450,
    batch_size=10,
    test_batch_sizes=[10],
    test_resolutions=[32],
    encode_input=True,
    encode_output=True,
    # encoding="channel-wise",
    # channel_dim=1,
)
data_processor = data_processor.to(device)
# print("Input encoder:", data_processor.in_normalizer)
# print("Output encoder:", data_processor.out_normalizer)
# print("in_normalizer mean:", getattr(data_processor.in_normalizer, "mean", None))
# print("out_normalizer mean:", getattr(data_processor.out_normalizer, "mean", None))
# Out:
# c:\workspace\no_playground\neuralop-playground\nopkit_pkg\nopkit\data.py:199: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ramps = torch.load(ramps_path)      # shape (n_samples, res_x, res_y)
# c:\workspace\no_playground\neuralop-playground\nopkit_pkg\nopkit\data.py:200: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   damage = torch.load(damage_path)    # shape (n_samples, res_x, res_y, time_steps)
# c:\workspace\no_playground\neuralop-playground\nopkit_pkg\nopkit\data.py:201: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   defgrad = torch.load(defgrad_path)  # shape (n_samples, res_x, res_y, time_steps)
# c:\workspace\no_playground\neuralop-playground\nopkit_pkg\nopkit\data.py:202: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   elec = torch.load(elec_path)        # shape (n_samples, res_x, res_y, time_steps)
# c:\workspace\no_playground\neuralop-playground\nopkit_pkg\nopkit\data.py:203: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   masks = torch.load(masks_path)      # shape (n_masks,   res_x, res_y)
# Loaded RAMPs      -> ..\data\damage_sensor\ramps_n500_res32.pt,	(torch.Size([500, 32, 32]))
# Loaded damage     -> ..\data\damage_sensor\damage_n500_t175_res32.pt,	(torch.Size([500, 32, 32, 175]))
# Loaded defgrad    -> ..\data\damage_sensor\defgrad_n500_t175_res32.pt,	(torch.Size([500, 32, 32, 175]))
# Loaded elec field -> ..\data\damage_sensor\elec_n500_t175_res32.pt,	(torch.Size([500, 32, 32, 175]))
# Loaded masks      -> ..\data\damage_sensor\mask_8.pt,	(torch.Size([1, 32, 32]))
# Loading total samples: 500, total masks: 1
# Loading train db: 450 samples, test db: 50 samples
# Train input shape: torch.Size([450, 3, 32, 32, 175]), Train output shape: torch.Size([450, 3, 32, 32, 175])
# Test input shape: torch.Size([50, 3, 32, 32, 175]), Test output shape: torch.Size([50, 3, 32, 32, 175])

# %%
# check data
index = 5
x = train_loader.dataset[index]['x']
y = train_loader.dataset[index]['y']
data_image(x, y, t=174, show_colorbar=True)
# Out:
# array([[<Axes: title={'center': 'Sensor signal $E_k(x, t)$'}>,
#         <Axes: title={'center': 'Mask $M(x)$'}>,
#         <Axes: title={'center': 'RAMPs field $\\Phi(x)$'}>],
#        [<Axes: title={'center': 'Electricity $E(x, t)$'}>,
#         <Axes: title={'center': 'Defgrad $F(x, t)$'}>,
#         <Axes: title={'center': 'Damage $D(x, t)$'}>]], dtype=object)

# %%
# check data
index = 49
x = test_loaders[32].dataset[index]['x']
y = test_loaders[32].dataset[index]['y']
data_image(x, y, t=174, show_colorbar=True)
# Out:
# array([[<Axes: title={'center': 'Sensor signal $E_k(x, t)$'}>,
#         <Axes: title={'center': 'Mask $M(x)$'}>,
#         <Axes: title={'center': 'RAMPs field $\\Phi(x)$'}>],
#        [<Axes: title={'center': 'Electricity $E(x, t)$'}>,
#         <Axes: title={'center': 'Defgrad $F(x, t)$'}>,
#         <Axes: title={'center': 'Damage $D(x, t)$'}>]], dtype=object)

# %%
# config model
model = FNO(
    n_modes=(8,8,10),
    in_channels=3,
    out_channels=3,
    hidden_channels=64,
    n_layers=4,
    projection_channel_ratio=2,
    positional_embedding = 'grid'
)
model = model.to(device)

n_params = count_model_params(model)
print(f'\nOur model has {n_params} parameters.')
sys.stdout.flush()
# Out:
# Our model has 12634435 parameters.

# %%
epochs=100
learning_rate=1e-4
scheduler_step=100
scheduler_gamma=0.5

# training setup
optimizer = AdamW(
    model.parameters(),
    lr=learning_rate, # learning rate
    weight_decay=1e-4
)

# use StepLR scheduler
scheduler = torch.optim.lr_scheduler.StepLR(
    optimizer, step_size=scheduler_step, gamma=scheduler_gamma
)

# losses setup
l2loss = LpLoss(d=2, p=2)
h1loss = H1Loss(d=2)

train_loss = h1loss # use H1 loss
eval_losses = {'h1': h1loss, 'l2':l2loss}

print('\n### MODEL ###\n', model)
print('\n### OPTIMIZER ###\n', optimizer)
print('\n### SCHEDULER ###\n', scheduler)
print('\n### LOSSES ###')
print(f'\n * Train: {train_loss}')
print(f'\n * Test: {eval_losses}')
sys.stdout.flush()
# Out:
# ### MODEL ###
#  FNO(
#   (positional_embedding): GridEmbeddingND()
#   (fno_blocks): FNOBlocks(
#     (convs): ModuleList(
#       (0-3): 4 x SpectralConv(
#         (weight): DenseTensor(shape=torch.Size([64, 64, 8, 8, 6]), rank=None)
#       )
#     )
#     (fno_skips): ModuleList(
#       (0-3): 4 x Flattened1dConv(
#         (conv): Conv1d(64, 64, kernel_size=(1,), stride=(1,), bias=False)
#       )
#     )
#     (channel_mlp): ModuleList(
#       (0-3): 4 x ChannelMLP(
#         (fcs): ModuleList(
#           (0): Conv1d(64, 32, kernel_size=(1,), stride=(1,))
#           (1): Conv1d(32, 64, kernel_size=(1,), stride=(1,))
#         )
#       )
#     )
#     (channel_mlp_skips): ModuleList(
#       (0-3): 4 x SoftGating()
#     )
#   )
#   (lifting): ChannelMLP(
#     (fcs): ModuleList(
#       (0): Conv1d(6, 128, kernel_size=(1,), stride=(1,))
#       (1): Conv1d(128, 64, kernel_size=(1,), stride=(1,))
#     )
#   )
#   (projection): ChannelMLP(
#     (fcs): ModuleList(
#       (0): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#       (1): Conv1d(128, 3, kernel_size=(1,), stride=(1,))
#     )
#   )
# )
#
# ### OPTIMIZER ###
#  AdamW (
# Parameter Group 0
#     betas: (0.9, 0.999)
#     correct_bias: True
#     eps: 1e-06
#     initial_lr: 0.0001
#     lr: 0.0001
#     weight_decay: 0.0001
# )
#
# ### SCHEDULER ###
#  <torch.optim.lr_scheduler.StepLR object at 0x0000022F85E5C1F0>
#
# ### LOSSES ###
#
#  * Train: <neuralop.losses.data_losses.H1Loss object at 0x0000022FF4199790>
#
#  * Test: {'h1': <neuralop.losses.data_losses.H1Loss object at 0x0000022FF4199790>, 'l2': <neuralop.losses.data_losses.LpLoss object at 0x0000022FF4199A30>}

# %%
# %%capture out
trainer = Trainer(
    model=model,
    n_epochs=epochs,
    data_processor=data_processor,
    device=device,
    mixed_precision=False,
    eval_interval=1,
    log_output=False,
    use_distributed=False,
    verbose=True,
    wandb_log = False
)

# train
trainer.train(
    train_loader=train_loader,
    test_loaders=test_loaders,
    optimizer=optimizer,
    scheduler=scheduler,
    regularizer=False,
    training_loss=train_loss,
    eval_losses=eval_losses,
    save_every=1,
    save_dir="./ckpt/fno3d_mask8/"
)
# Out:
# Training on 450 samples
# Testing on [50] samples         on resolutions [32].
# Raw outputs of shape torch.Size([10, 3, 32, 32, 175])
# [0] time=533.56, avg_loss=95.5580, train_err=955.5803
# Eval: 32_h1=68.2523, 32_l2=44.6677
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [1] time=523.96, avg_loss=90.2773, train_err=902.7731
# Eval: 32_h1=53.6668, 32_l2=51.6972
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [2] time=522.72, avg_loss=47.7174, train_err=477.1738
# Eval: 32_h1=26.1773, 32_l2=96.7451
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [3] time=522.83, avg_loss=25.1555, train_err=251.5546
# Eval: 32_h1=12.2904, 32_l2=68.1348
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [4] time=522.80, avg_loss=10.4938, train_err=104.9377
# Eval: 32_h1=5.4313, 32_l2=26.2817
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [5] time=522.84, avg_loss=6.0452, train_err=60.4525
# Eval: 32_h1=4.0463, 32_l2=24.1524
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [6] time=522.77, avg_loss=4.8128, train_err=48.1279
# Eval: 32_h1=3.4576, 32_l2=18.0001
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [7] time=523.05, avg_loss=4.2012, train_err=42.0121
# Eval: 32_h1=2.9795, 32_l2=13.6292
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [8] time=522.86, avg_loss=3.7823, train_err=37.8231
# Eval: 32_h1=2.6846, 32_l2=10.7436
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [9] time=523.32, avg_loss=3.4814, train_err=34.8138
# Eval: 32_h1=2.5387, 32_l2=8.9425
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [10] time=524.95, avg_loss=3.2036, train_err=32.0360
# Eval: 32_h1=2.3241, 32_l2=7.6168
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [11] time=526.46, avg_loss=3.0060, train_err=30.0597
# Eval: 32_h1=2.1528, 32_l2=6.8456
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [12] time=530.73, avg_loss=2.8762, train_err=28.7616
# Eval: 32_h1=2.0404, 32_l2=6.3134
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [13] time=525.18, avg_loss=2.7627, train_err=27.6266
# Eval: 32_h1=2.2559, 32_l2=6.0712
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [14] time=525.95, avg_loss=2.6458, train_err=26.4581
# Eval: 32_h1=2.0378, 32_l2=5.7778
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [15] time=525.06, avg_loss=2.5760, train_err=25.7600
# Eval: 32_h1=1.9013, 32_l2=5.4782
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [16] time=524.97, avg_loss=2.4229, train_err=24.2288
# Eval: 32_h1=1.7948, 32_l2=5.1813
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [17] time=525.01, avg_loss=2.3778, train_err=23.7775
# Eval: 32_h1=1.7918, 32_l2=5.0387
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [18] time=525.07, avg_loss=2.3200, train_err=23.1999
# Eval: 32_h1=1.6967, 32_l2=4.8462
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [19] time=524.40, avg_loss=2.2907, train_err=22.9072
# Eval: 32_h1=1.7136, 32_l2=4.6582
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [20] time=524.65, avg_loss=2.2364, train_err=22.3636
# Eval: 32_h1=1.6429, 32_l2=4.4858
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [21] time=524.66, avg_loss=2.1757, train_err=21.7569
# Eval: 32_h1=1.6247, 32_l2=4.3220
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [22] time=524.55, avg_loss=2.1247, train_err=21.2472
# Eval: 32_h1=1.5763, 32_l2=4.1897
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [23] time=524.63, avg_loss=2.1258, train_err=21.2579
# Eval: 32_h1=1.5501, 32_l2=3.9532
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [24] time=524.64, avg_loss=2.0694, train_err=20.6945
# Eval: 32_h1=1.5839, 32_l2=3.8103
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [25] time=524.76, avg_loss=2.0571, train_err=20.5705
# Eval: 32_h1=1.5325, 32_l2=3.6950
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [26] time=524.43, avg_loss=2.0389, train_err=20.3892
# Eval: 32_h1=1.5264, 32_l2=3.5297
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [27] time=524.71, avg_loss=2.0298, train_err=20.2980
# Eval: 32_h1=1.6294, 32_l2=3.4633
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [28] time=524.29, avg_loss=1.9987, train_err=19.9874
# Eval: 32_h1=1.5107, 32_l2=3.2713
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [29] time=523.40, avg_loss=1.9814, train_err=19.8143
# Eval: 32_h1=1.4760, 32_l2=3.2055
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [30] time=523.37, avg_loss=2.0723, train_err=20.7232
# Eval: 32_h1=1.6928, 32_l2=3.0886
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [31] time=523.54, avg_loss=1.9521, train_err=19.5212
# Eval: 32_h1=1.5127, 32_l2=2.9571
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [32] time=523.37, avg_loss=1.9214, train_err=19.2144
# Eval: 32_h1=1.4282, 32_l2=2.8178
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [33] time=523.33, avg_loss=1.9805, train_err=19.8050
# Eval: 32_h1=1.5274, 32_l2=2.7554
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [34] time=523.32, avg_loss=1.9098, train_err=19.0985
# Eval: 32_h1=1.4227, 32_l2=2.6588
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [35] time=523.43, avg_loss=1.8333, train_err=18.3329
# Eval: 32_h1=1.3945, 32_l2=2.5592
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [36] time=523.46, avg_loss=1.8623, train_err=18.6232
# Eval: 32_h1=1.3935, 32_l2=2.4417
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [37] time=523.24, avg_loss=1.9579, train_err=19.5793
# Eval: 32_h1=1.4608, 32_l2=2.4200
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [38] time=523.83, avg_loss=1.8663, train_err=18.6630
# Eval: 32_h1=1.4224, 32_l2=2.3158
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [39] time=524.85, avg_loss=1.8344, train_err=18.3442
# Eval: 32_h1=1.3687, 32_l2=2.2361
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [40] time=524.63, avg_loss=1.8265, train_err=18.2645
# Eval: 32_h1=1.3953, 32_l2=2.1937
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [41] time=524.64, avg_loss=1.8113, train_err=18.1126
# Eval: 32_h1=1.3871, 32_l2=2.1813
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [42] time=524.51, avg_loss=1.8391, train_err=18.3914
# Eval: 32_h1=1.4207, 32_l2=2.0939
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [43] time=524.73, avg_loss=1.8413, train_err=18.4132
# Eval: 32_h1=1.3722, 32_l2=2.0104
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [44] time=524.64, avg_loss=1.8356, train_err=18.3557
# Eval: 32_h1=1.3550, 32_l2=1.9109
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [45] time=524.63, avg_loss=1.8424, train_err=18.4244
# Eval: 32_h1=1.4191, 32_l2=1.9804
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [46] time=524.52, avg_loss=1.7969, train_err=17.9688
# Eval: 32_h1=1.3379, 32_l2=1.8520
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [47] time=524.68, avg_loss=1.8199, train_err=18.1990
# Eval: 32_h1=1.5606, 32_l2=1.9364
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [48] time=523.17, avg_loss=1.7232, train_err=17.2323
# Eval: 32_h1=1.3478, 32_l2=1.8143
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [49] time=522.73, avg_loss=1.7313, train_err=17.3127
# Eval: 32_h1=1.3297, 32_l2=1.8205
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [50] time=522.64, avg_loss=1.7499, train_err=17.4991
# Eval: 32_h1=1.3638, 32_l2=1.7306
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [51] time=524.17, avg_loss=1.7461, train_err=17.4611
# Eval: 32_h1=1.2840, 32_l2=1.6793
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [52] time=522.75, avg_loss=1.7711, train_err=17.7110
# Eval: 32_h1=1.2662, 32_l2=1.6565
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [53] time=522.71, avg_loss=1.6949, train_err=16.9494
# Eval: 32_h1=1.3276, 32_l2=1.6330
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [54] time=523.11, avg_loss=1.6654, train_err=16.6537
# Eval: 32_h1=1.2706, 32_l2=1.6113
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [55] time=522.77, avg_loss=1.7082, train_err=17.0822
# Eval: 32_h1=1.2485, 32_l2=1.6030
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [56] time=522.67, avg_loss=1.6752, train_err=16.7522
# Eval: 32_h1=1.2721, 32_l2=1.5597
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [57] time=523.20, avg_loss=1.7485, train_err=17.4847
# Eval: 32_h1=1.2766, 32_l2=1.5395
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [58] time=525.13, avg_loss=1.6620, train_err=16.6204
# Eval: 32_h1=1.2710, 32_l2=1.5534
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [59] time=524.88, avg_loss=1.6209, train_err=16.2094
# Eval: 32_h1=1.2585, 32_l2=1.5303
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [60] time=524.95, avg_loss=1.6508, train_err=16.5085
# Eval: 32_h1=1.3331, 32_l2=1.5104
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [61] time=524.82, avg_loss=1.6560, train_err=16.5600
# Eval: 32_h1=1.2271, 32_l2=1.5095
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [62] time=528.61, avg_loss=1.6508, train_err=16.5082
# Eval: 32_h1=1.4172, 32_l2=1.6716
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [63] time=546.81, avg_loss=1.6132, train_err=16.1318
# Eval: 32_h1=1.2841, 32_l2=1.4913
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [64] time=540.37, avg_loss=1.6100, train_err=16.1003
# Eval: 32_h1=1.2134, 32_l2=1.4334
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [65] time=547.33, avg_loss=1.6285, train_err=16.2853
# Eval: 32_h1=1.2534, 32_l2=1.4622
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [66] time=545.72, avg_loss=1.5805, train_err=15.8047
# Eval: 32_h1=1.2431, 32_l2=1.4934
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [67] time=550.27, avg_loss=1.6511, train_err=16.5111
# Eval: 32_h1=1.3300, 32_l2=1.5417
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [68] time=543.18, avg_loss=1.6125, train_err=16.1250
# Eval: 32_h1=1.2565, 32_l2=1.4694
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [69] time=553.18, avg_loss=1.6059, train_err=16.0593
# Eval: 32_h1=1.2030, 32_l2=1.4125
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [70] time=547.30, avg_loss=1.5589, train_err=15.5893
# Eval: 32_h1=1.1834, 32_l2=1.3998
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [71] time=542.91, avg_loss=1.5930, train_err=15.9304
# Eval: 32_h1=1.2491, 32_l2=1.4212
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [72] time=556.03, avg_loss=1.5785, train_err=15.7847
# Eval: 32_h1=1.2271, 32_l2=1.4169
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [73] time=549.02, avg_loss=1.5547, train_err=15.5470
# Eval: 32_h1=1.2676, 32_l2=1.4260
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [74] time=553.11, avg_loss=1.5347, train_err=15.3472
# Eval: 32_h1=1.1907, 32_l2=1.3721
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [75] time=563.22, avg_loss=1.5315, train_err=15.3152
# Eval: 32_h1=1.1976, 32_l2=1.3965
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [76] time=543.33, avg_loss=1.5182, train_err=15.1818
# Eval: 32_h1=1.3494, 32_l2=1.4500
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [77] time=526.47, avg_loss=1.5043, train_err=15.0427
# Eval: 32_h1=1.2798, 32_l2=1.3816
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [78] time=518.59, avg_loss=1.5630, train_err=15.6295
# Eval: 32_h1=1.2155, 32_l2=1.3596
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [79] time=524.83, avg_loss=1.5261, train_err=15.2609
# Eval: 32_h1=1.1412, 32_l2=1.3252
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [80] time=522.19, avg_loss=1.5154, train_err=15.1536
# Eval: 32_h1=1.1808, 32_l2=1.3703
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [81] time=519.17, avg_loss=1.5121, train_err=15.1208
# Eval: 32_h1=1.2090, 32_l2=1.3766
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# [82] time=519.43, avg_loss=1.4874, train_err=14.8738
# Eval: 32_h1=1.1693, 32_l2=1.3750
# [Rank 0]: saved training state to ./ckpt/fno3d_mask8/
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 16
#       2 trainer = Trainer(
#       3     model=model,
#       4     n_epochs=epochs,
#    (...)
#      12     wandb_log = False
#      13 )
#      15 # train
# ---> 16 trainer.train(
#      17     train_loader=train_loader,
#      18     test_loaders=test_loaders,
#      19     optimizer=optimizer,
#      20     scheduler=scheduler,
#      21     regularizer=False,
#      22     training_loss=train_loss,
#      23     eval_losses=eval_losses,
#      24     save_every=1,
#      25     save_dir="./ckpt/fno3d_mask8/"
#      26 )
#
# File C:\workspace\no_playground\neuraloperator\neuralop\training\trainer.py:209, in Trainer.train(self, train_loader, test_loaders, optimizer, scheduler, regularizer, training_loss, eval_losses, save_every, save_best, save_dir, resume_from_dir)
#     205     sys.stdout.flush()
#     207 for epoch in range(self.start_epoch, self.n_epochs):
#     208     train_err, avg_loss, avg_lasso_loss, epoch_train_time =\
# --> 209           self.train_one_epoch(epoch, train_loader, training_loss)
#     210     epoch_metrics = dict(
#     211         train_err=train_err,
#     212         avg_loss=avg_loss,
#     213         avg_lasso_loss=avg_lasso_loss,
#     214         epoch_train_time=epoch_train_time
#     215     )
#     217     if epoch % self.eval_interval == 0:
#     218         # evaluate and gather metrics across each loader in test_loaders
#
# File C:\workspace\no_playground\neuraloperator\neuralop\training\trainer.py:273, in Trainer.train_one_epoch(self, epoch, train_loader, training_loss)
#     270 loss.backward()
#     271 self.optimizer.step()
# --> 273 train_err += loss.item()
#     274 with torch.no_grad():
#     275     avg_loss += loss.item()
#
# KeyboardInterrupt:

# %%
# plot train and eval loss
import re
import matplotlib.pyplot as plt

with open("log_mask8.txt", 'r') as f:
    log = f.read()

train_loss = [float(x) for x in re.findall(r"avg_loss=([0-9.]+)", log)]
eval_loss = [float(x) for x in re.findall(r"32_h1=([0-9.]+)", log)]

train_loss_rel = [x / train_loss[0] for x in train_loss]
eval_loss_rel = [x / eval_loss[0] for x in eval_loss]

# plot
fig, ax = plt.subplots()
ax.plot(train_loss_rel, label='Train')
ax.plot(eval_loss_rel, label='Eval')
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')
ax.set(xlim=[0, len(train_loss)], ylim=[0, 1])
ax.legend()
plt.show()

# %%
model.save_checkpoint("./model", save_name="fno3d_mask8")

# %%
# reload
model_reload = FNO.from_checkpoint("./model", save_name="fno3d_mask8")

# %%
# plot prediction
# model_use = model
model_use = model_reload.to(device)

test_samples = test_loaders[32].dataset
idx = 49

data = test_samples[idx]

data_processor.to(device)
data_processor.eval()
data = data_processor.preprocess(data, batched=True)


x = data['x']
y = data['y']
out = model_use(x)

# postprocess data
out, _ = data_processor.postprocess(out, data)

t = -1

vmins = [1e6, 1.01, 0.05]
vmaxs = [7.5e6, 1.04, 0.6]
pred_voxel(y.cpu(), out.squeeze().detach().cpu(), t=t,
           show_colorbar=True, vmins=vmins, vmaxs=vmaxs, plot_method='contourf', level=20, cmap='viridis')
# Out:
# array([[<Axes3D: title={'center': 'Electric Field'}>,
#         <Axes3D: title={'center': 'Deformation Field'}>,
#         <Axes3D: title={'center': 'Damage Indicator'}>],
#        [<Axes3D: >, <Axes3D: >, <Axes3D: >]], dtype=object)

# %%
from nopkit.plot import pred_voxel_anim

t_range = range(150, 175)

vmins = [1.5e6, 1.005, 0.1]
vmaxs = [7.5e6, 1.04, 0.6]

save_path = f'./media/mask8_id{idx}_3d.gif'
pred_voxel_anim(y.cpu(), out.squeeze().detach().cpu(), t_range=t_range,
          save_path=save_path, fps=2,
          show_colorbar=True, vmins=vmins, vmaxs=vmaxs, plot_method='contourf')
# Out:
# save to ./media/mask8_id49_3d.gif
